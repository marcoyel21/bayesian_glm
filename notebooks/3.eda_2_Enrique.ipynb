# %% [markdown]
# # Notas
#
# Filtros aplicados:
# - Estado:
#     - Ciudad de México
# - Destino del crédito:
#     - Adquisición de Vivienda Nueva
#     - Adquisición de Vivienda Usada

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import geopandas as gpd


sns.set_style("darkgrid")
plt.rc("figure", figsize=(16, 6))
pd.set_option("display.max_columns",100)

# %% [markdown]
# # Datos

# %%
df = pd.read_csv(
    "../data/data1.csv",
    encoding="latin-1"
)
df.head()
# Out:
#            sector  cve_periodo nombre_publicacion dl_estado   dl_municipio
# 0  BANCA MÚLTIPLE       201912            CIBanco  VERACRUZ      TANTOYUCA  \
# 1  BANCA MÚLTIPLE       201912            CIBanco  VERACRUZ  TIERRA BLANCA
# 2  BANCA MÚLTIPLE       201912            CIBanco  VERACRUZ  URSULO GALVAN
# 3  BANCA MÚLTIPLE       201912            CIBanco  VERACRUZ         XALAPA
# 4  BANCA MÚLTIPLE       201912            CIBanco   YUCATAN      CANSAHCAB
#
#    dat_ingreso_mensual_bruto  dat_valor_vivienda_originacion
# 0                     6392.0                         28033.0  \
# 1                     8496.0                         13341.0
# 2                     4533.0                         19521.0
# 3                     3434.0                         14897.0
# 4                     3878.0                         12291.0
#
#       tipo_acreditado dl_tipo_comprobacion  dat_ai_edad_acred  dl_genero
# 0  Asalariado Privado           Asalariado                 33   Femenino  \
# 1  Asalariado Privado           Asalariado                 25  Masculino
# 2  Asalariado Privado           Asalariado                 43  Masculino
# 3  Asalariado Privado           Asalariado                 28   Femenino
# 4  Asalariado Privado           Asalariado                 44   Femenino
#
#   numero de crédito  dat_monto_orig_cred
# 0       Crédito 760              28033.0  \
# 1       Crédito 714              13341.0
# 2       Crédito 757              19521.0
# 3       Crédito 751              14897.0
# 4       Crédito 976              12291.0
#
#                          dl_destino_credito        dl_producto_hipotecario
# 0  Mejoras, Ampliaciones y/o Remodelaciones  Mejora Tu Hogar de Infonavit   \
# 1  Mejoras, Ampliaciones y/o Remodelaciones  Mejora Tu Hogar de Infonavit
# 2  Mejoras, Ampliaciones y/o Remodelaciones  Mejora Tu Hogar de Infonavit
# 3  Mejoras, Ampliaciones y/o Remodelaciones  Mejora Tu Hogar de Infonavit
# 4  Mejoras, Ampliaciones y/o Remodelaciones  Mejora Tu Hogar de Infonavit
#
#         Tipo de Crédito                               dl_segmento_vivienda
# 0  Sin cofinanciamiento  Remodelación o mejoramiento con gtía otorg Ban...  \
# 1  Sin cofinanciamiento  Remodelación o mejoramiento con gtía otorg Ban...
# 2  Sin cofinanciamiento  Remodelación o mejoramiento con gtía otorg Ban...
# 3  Sin cofinanciamiento  Remodelación o mejoramiento con gtía otorg Ban...
# 4  Sin cofinanciamiento  Remodelación o mejoramiento con gtía otorg Ban...
#
#    tasa_ponderada
# 0            16.5
# 1            16.5
# 2            16.5
# 3            16.5
# 4            16.5

# %%
cdmx = gpd.read_file('../data/mapa_mexico/')\
    .query('CVE_EDO=="09"')\
    .set_index('CLAVE')
cdmx.boundary.plot();

# %%
cdmx
# Out:
#                       NOM_MUN NOMEDO CVE_EDO CVE_MUNI        Area
# CLAVE
# 09005       Gustavo A. Madero   D.F.      09      005   87.445402  \
# 09002            Azcapotzalco   D.F.      09      002   33.420781
# 09016          Miguel Hidalgo   D.F.      09      016   45.938498
# 09015              Cuauhtemoc   D.F.      09      015   32.383814
# 09017     Venustiano Carranza   D.F.      09      017   33.599971
# 09006               Iztacalco   D.F.      09      006   23.123819
# 09014           Benito Juarez   D.F.      09      014   26.400780
# 09010          Alvaro Obregon   D.F.      09      010   95.434621
# 09004   Cuajimalpa de Morelos   D.F.      09      004   70.047016
# 09007              Iztapalapa   D.F.      09      007  113.106540
# 09003                Coyoacan   D.F.      09      003   53.669966
# 09008  La Magdalena Contreras   D.F.      09      008   63.279407
# 09011                 Tlahuac   D.F.      09      011   85.982910
# 09013              Xochimilco   D.F.      09      013  118.618725
# 09012                 Tlalpan   D.F.      09      012  308.285967
# 09009              Milpa Alta   D.F.      09      009  285.574948
#
#                                                 geometry
# CLAVE
# 09005  POLYGON ((-99.11705 19.58909, -99.11748 19.588...
# 09002  POLYGON ((-99.15688 19.50231, -99.15684 19.502...
# 09016  POLYGON ((-99.20666 19.47052, -99.20610 19.470...
# 09015  POLYGON ((-99.14274 19.46446, -99.14243 19.464...
# 09017  POLYGON ((-99.05068 19.44927, -99.04696 19.440...
# 09006  POLYGON ((-99.12534 19.40359, -99.12184 19.404...
# 09014  POLYGON ((-99.13543 19.40262, -99.13557 19.402...
# 09010  POLYGON ((-99.24694 19.38558, -99.24584 19.386...
# 09004  POLYGON ((-99.25510 19.40213, -99.25499 19.401...
# 09007  POLYGON ((-99.05769 19.39993, -99.03938 19.391...
# 09003  POLYGON ((-99.17129 19.35900, -99.16969 19.357...
# 09008  POLYGON ((-99.23439 19.29485, -99.23441 19.294...
# 09011  POLYGON ((-99.06891 19.28390, -99.06665 19.286...
# 09013  POLYGON ((-99.10061 19.29925, -99.10053 19.299...
# 09012  POLYGON ((-99.21897 19.31069, -99.21806 19.309...
# 09009  POLYGON ((-98.96651 19.19740, -98.96632 19.192...

# %%
cdmx.plot("Area", legend=True);

# %% [markdown]
# # Transformación 1

# %%
dicc_alc_cve = {
    'ALVARO OBREGON': '09010',
    'AZCAPOTZALCO': '09002',
    'BENITO JUAREZ': '09014',
    'COYOACAN': '09003',
    'CUAJIMALPA DE MORELOS': '09004',
    'CUAUHTEMOC': '09015',
    'GUSTAVO A. MADERO': '09005',
    'IZTACALCO': '09006',
    'IZTAPALAPA': '09007',
    'LA MAGDALENA CONTRERAS': '09008',
    'MIGUEL HIDALGO': '09016',
    'MILPA ALTA': '09009',
    'TLAHUAC': '09011', 
    'TLALPAN': '09012',
    'VENUSTIANO CARRANZA': '09017',
    'XOCHIMILCO': '09013'
}

# %%
df['pct_enganche'] = 1-df['dat_monto_orig_cred']/df['dat_valor_vivienda_originacion']
df = df[
    (df.tasa_ponderada < 20)
    & (df['pct_enganche'] > 0)
]

df['fecha_originacion'] = pd.to_datetime(df.cve_periodo, format="%Y%m")

df = df.assign(clave=lambda x: x["dl_municipio"].map(dicc_alc_cve))

# %%
df[
    df.dl_estado == "CIUDAD DE MÉXICO"
][["dl_municipio","clave"]].value_counts(dropna=False)
# Out:
# dl_municipio            clave
# BENITO JUAREZ           09014    14238
# CUAUHTEMOC              09015     7568
# MIGUEL HIDALGO          09016     6861
# ALVARO OBREGON          09010     6028
# COYOACAN                09003     5344
# AZCAPOTZALCO            09002     4282
# GUSTAVO A. MADERO       09005     4215
# TLALPAN                 09012     3908
# IZTACALCO               09006     3540
# CUAJIMALPA DE MORELOS   09004     2907
# IZTAPALAPA              09007     2552
# VENUSTIANO CARRANZA     09017     2534
# LA MAGDALENA CONTRERAS  09008      862
# XOCHIMILCO              09013      712
# TLAHUAC                 09011      343
# MILPA ALTA              09009       35
# Name: count, dtype: int64

# %% [markdown]
# # Filtro 1

# %%
df.isna().sum()
# Out:
# sector                                 0
# cve_periodo                            0
# nombre_publicacion                     0
# dl_estado                              0
# dl_municipio                           0
# dat_ingreso_mensual_bruto              0
# dat_valor_vivienda_originacion         0
# tipo_acreditado                        0
# dl_tipo_comprobacion                   0
# dat_ai_edad_acred                      0
# dl_genero                              0
# numero de crédito                      0
# dat_monto_orig_cred                    0
# dl_destino_credito                     0
# dl_producto_hipotecario             1016
# Tipo de Crédito                        0
# dl_segmento_vivienda                   0
# tasa_ponderada                         0
# pct_enganche                           0
# fecha_originacion                      0
# clave                             498127
# dtype: int64

# %%
df.dl_estado.value_counts().plot(kind='bar');

# %%
df.dl_destino_credito.value_counts().plot(kind='bar');

# %%
df = df[
    (df.dl_estado == "CIUDAD DE MÉXICO")
    & (df.dl_destino_credito.isin(["Adquisición de Vivienda Nueva", "Adquisición de Vivienda Usada"]))
]

# %% [markdown]
# # Exploración 1

# %% [markdown]
# ## Continuas

# %%
cont_vars = [
    "dat_ingreso_mensual_bruto",
    "dat_valor_vivienda_originacion",
    "dat_ai_edad_acred",
    "dat_monto_orig_cred",
    "tasa_ponderada",
    "pct_enganche",
]

for var in cont_vars:
    df[var].hist(bins=35);
    plt.title(var);
    plt.show();

# %% [markdown]
# ### Excluyendo outliers

# %%
for var in cont_vars:
    quant_var_max = df[var].quantile(.975)
    quant_var_min = df[var].quantile(.015)
    df[
        (df[var] <= quant_var_max)
        & (df[var] >= quant_var_min) 
    ][var].hist(bins=35);
    plt.title(var);
    plt.show();

# %% [markdown]
# ## Discretas

# %%
cat_vars = [
    "nombre_publicacion",
    "sector",
    "dl_municipio",
    "tipo_acreditado",
    "dl_tipo_comprobacion",
    "dl_genero",
    "dl_destino_credito",
    "dl_producto_hipotecario",
    "Tipo de Crédito",
    "dl_segmento_vivienda",
    
]

for var in cat_vars:
    df[var].value_counts().head(20).plot(kind='barh');
    plt.title(var);
    plt.show();

# %%
df[
    df.dat_monto_orig_cred < 15000000
].plot.scatter(x='dat_monto_orig_cred', y="tasa_ponderada");

# %%
df_pivot_1 = df.pivot_table(
    index = "clave",
    aggfunc={
        'dat_monto_orig_cred':[sum, 'count','mean', 'median'],
        'dat_ai_edad_acred':['mean'],
        'dat_ingreso_mensual_bruto':['mean', 'median'],
        'tasa_ponderada':['mean'],
        'pct_enganche':['mean'],
    }
)

df_pivot_1.columns = [
    "edad_promedio",
    "ingreso_promedio",
    "mediana_ingreso",
    
    "creditos",
    "promedio_monto",
    "mediana_monto",
    "monto_originado",
    
    "enganche_promedio",
    "tasa_promedio",
    

]

df_pivot_1.head()
# Out:
#        edad_promedio  ingreso_promedio  mediana_ingreso  creditos
# clave
# 09002      40.986345      9.102076e+04        48974.000      3735  \
# 09003      43.870161      4.204994e+05        66758.000      4521
# 09004      41.950402      1.283604e+06       113078.725      2238
# 09005      41.880933      1.183329e+05        44343.000      3729
# 09006      40.172653      7.010649e+05        38970.905      3174
#
#        promedio_monto  mediana_monto  monto_originado  enganche_promedio
# clave
# 09002    1.710850e+06    1540443.030     6.390025e+09           0.318225  \
# 09003    2.642714e+06    2064917.010     1.194771e+10           0.345433
# 09004    4.248170e+06    2743340.935     9.507405e+09           0.375892
# 09005    1.710723e+06    1413652.000     6.379285e+09           0.312472
# 09006    1.368010e+06    1240803.920     4.342063e+09           0.296234
#
#        tasa_promedio
# clave
# 09002       9.592770
# 09003       9.498515
# 09004       9.386085
# 09005       9.600419
# 09006       9.666157

# %%
df_map_plot = pd.concat(
    [
        cdmx,
        df_pivot_1
    ],
    axis=1
)

df_map_plot.tail()
# Out:
#                       NOM_MUN NOMEDO CVE_EDO CVE_MUNI        Area
# 09008  La Magdalena Contreras   D.F.      09      008   63.279407  \
# 09011                 Tlahuac   D.F.      09      011   85.982910
# 09013              Xochimilco   D.F.      09      013  118.618725
# 09012                 Tlalpan   D.F.      09      012  308.285967
# 09009              Milpa Alta   D.F.      09      009  285.574948
#
#                                                 geometry  edad_promedio
# 09008  POLYGON ((-99.23439 19.29485, -99.23441 19.294...      43.422648  \
# 09011  POLYGON ((-99.06891 19.28390, -99.06665 19.286...      42.243636
# 09013  POLYGON ((-99.10061 19.29925, -99.10053 19.299...      43.235507
# 09012  POLYGON ((-99.21897 19.31069, -99.21806 19.309...      43.385192
# 09009  POLYGON ((-98.96651 19.19740, -98.96632 19.192...      39.592593
#
#        ingreso_promedio  mediana_ingreso  creditos  promedio_monto
# 09008     392281.240223        106667.35       627    3.959338e+06  \
# 09011      56520.868807         36986.00       275    1.289109e+06
# 09013     149361.878906         61105.50       552    2.315640e+06
# 09012     208271.771335         70000.00      3201    2.780565e+06
# 09009      27535.599630          8900.80        27    2.092787e+06
#
#        mediana_monto  monto_originado  enganche_promedio  tasa_promedio
# 09008     3400000.00     2.482505e+09           0.379231       9.379924
# 09011      982300.00     3.545049e+08           0.287166       9.932441
# 09013     2000000.00     1.278233e+09           0.313895       9.728321
# 09012     2100000.00     8.900588e+09           0.334605       9.542340
# 09009     1525736.42     5.650525e+07           0.401897       9.214937

# %%
vars_to_plot = [
    "edad_promedio",
    "ingreso_promedio",
    "mediana_ingreso",
    "creditos",
    "promedio_monto",
    "enganche_promedio",
    "tasa_promedio",
]

for var in vars_to_plot:
    df_map_plot.plot(var, legend=True, cmap="OrRd");
    plt.title(var)
    plt.show();

# %%
df['fecha_originacion'] = pd.to_datetime(df.cve_periodo, format="%Y%m")
df_pivot_1 = df.pivot_table(
    index = df.fecha_originacion.dt.to_period('M'),
    aggfunc={
        'dat_monto_orig_cred':[sum, 'count','mean', 'median'],
        'dat_ai_edad_acred':['mean'],
        'dat_ingreso_mensual_bruto':['mean', 'median']
    }
)

df_pivot_1.columns = [
    "edad_promedio",
    "ingreso_promedio",
    "mediana_ingreso",
    
    "creditos",
    "promedio_monto",
    "mediana_monto",
    "monto_originado",

]

df_pivot_1.head()
# Out:
#                    edad_promedio  ingreso_promedio  mediana_ingreso  creditos
# fecha_originacion
# 2019-01                43.555237     202794.042310        65000.100       697  \
# 2019-02                42.308547     153909.737923        62705.695      1170
# 2019-03                42.631261     175474.526054        58693.280      1158
# 2019-04                42.773730     133318.833020        63854.000      1043
# 2019-05                42.639560     138748.474725        61429.000      1365
#
#                    promedio_monto  mediana_monto  monto_originado
# fecha_originacion
# 2019-01              2.362374e+06     1651000.00     1.646575e+09
# 2019-02              2.506796e+06     1839751.24     2.932951e+09
# 2019-03              2.347217e+06     1700000.00     2.718077e+09
# 2019-04              2.286044e+06     1700000.00     2.384343e+09
# 2019-05              2.226750e+06     1610000.00     3.039514e+09

# %%
df[
    (df.tasa_ponderada < 2.5)
    & (df.dl_estado == "CIUDAD DE MÉXICO")
].nombre_publicacion.value_counts()
# Out:
# nombre_publicacion
# BBVA México    150
# Banamex         43
# Santander       11
# Nafin            1
# Name: count, dtype: int64

# %%
df['fecha_originacion'] = pd.to_datetime(df.cve_periodo, format="%Y%m")

for year in [2019,2020,2021,2022,2023]:
    df[
        (df.dl_estado == "CIUDAD DE MÉXICO")
        & (df.dl_destino_credito.isin(["Adquisición de Vivienda Nueva", "Adquisición de Vivienda Usada"]))
        & (df.fecha_originacion.dt.year == year)
    ].plot.scatter(x='pct_enganche', y="tasa_ponderada");
    plt.show();

# %%
df_pivot_1.monto_originado.plot();

# %%
df.to_csv("../data/datos_filtados_1.csv",index=False)

# %% [markdown]
# # Referencias
#
# - https://mc-stan.org/docs/stan-users-guide/linear-regression.html
# - https://geopandas.org/en/stable/index.html
